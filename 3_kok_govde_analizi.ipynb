# %% [markdown]
# Kök ve Gövde (lemma) bulma
#
# -stemming: porter stemmer
#
#
# -lemmatization: word net lemmatizer

# %%
import nltk
nltk.download("wordnet") #lemma bulmak için gerekli wordnet veritabanı
nltk.download("omw-1.4") #wordnet için ek dil desteği
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
#stemming - kök
from nltk.stem import PorterStemmer #ingilizce için popüler stemmer algoritması
stemmer= PorterStemmer() #porter stemmer nesnesi oluştur
words_stem=["playing","played","plays","happier","happily","studying","studies"]

stems = [stemmer.stem(w) for w in words_stem]
print(f"Orijinal: {words_stem}")
print(f"Stems: {stems}")
# Out:
# Orijinal: ['playing', 'played', 'plays', 'happier', 'happily', 'studying', 'studies']
# Stems: ['play', 'play', 'play', 'happier', 'happili', 'studi', 'studi']

# %%
#lemmatization - gövde
from nltk.stem import WordNetLemmatizer

lemmatizer=WordNetLemmatizer()

words_lemma=["running","ran","gone","better","children"]

lemmas=[lemmatizer.lemmatize(w) for w in words_lemma]
print(f"Lemmas: {lemmas}")
# Out:
# Lemmas: ['running', 'ran', 'gone', 'better', 'child']
